# %% [markdown]
# # Création des dossiers por VGG16 DataSet dans Tensorflow
#
# # Classification pour obtenir les dossiers dans le training dataset

# %%
from __future__ import print_function
import pandas as pd
import shutil
import os
import sys

# %%
train_csv=pd.read_csv("data_saved_train.csv")
fichier_train=train_csv.copy()
fichier_train=fichier_train.drop(columns=["Unnamed: 0","image_path","label"])
fichier_train.head()
# Out:
#                                      id label_name
# 0  785b4383b12106dd172306d427d8f7b2.jpg    Kitchen
# 1  45d0af2c709de47268c80c35a117de44.jpg      Decor
# 2  64b463dc0b75ae40a848498c657041e6.jpg  Computers
# 3  6b5cdfe68595fbcab0e05dc625d3d66a.jpg     Beauty
# 4  e86daf9ebcdfc5c5dd088cdb7f8f8db6.jpg  Computers

# %%
fichier_train = fichier_train.set_index(['id'])
fichier_train.head()
# Out:
#                                      label_name
# id
# 785b4383b12106dd172306d427d8f7b2.jpg    Kitchen
# 45d0af2c709de47268c80c35a117de44.jpg      Decor
# 64b463dc0b75ae40a848498c657041e6.jpg  Computers
# 6b5cdfe68595fbcab0e05dc625d3d66a.jpg     Beauty
# e86daf9ebcdfc5c5dd088cdb7f8f8db6.jpg  Computers

# %%
fichier_train.shape
# Out:
# (787, 1)

# %%
fichier_train.to_csv('fichier_train_with_labels.csv',index=True)

# %%
train_data=pd.read_csv("fichier_train_with_labels.csv")
train_label=train_data.copy()
#train_label = train_label.set_index(['id'])
train_label.head()
# Out:
#                                      id label_name
# 0  785b4383b12106dd172306d427d8f7b2.jpg    Kitchen
# 1  45d0af2c709de47268c80c35a117de44.jpg      Decor
# 2  64b463dc0b75ae40a848498c657041e6.jpg  Computers
# 3  6b5cdfe68595fbcab0e05dc625d3d66a.jpg     Beauty
# 4  e86daf9ebcdfc5c5dd088cdb7f8f8db6.jpg  Computers

# %%
#Directories 
#labels = pd.read_csv('fichier_train_with_labels.csv')
labels=train_label

images_dir =r'C:\Users\kherm\Documents\Openclassrooms\projet 6\Flipkart\Images'
train = r"C:\Users\kherm\Documents\Openclassrooms\projet 6\Flipkart\train"

# %%
if not os.path.exists(train):
    os.mkdir(train)

for filename, class_name in labels.values:
    # Create subdirectory with `class_name`
    if not os.path.exists(train + str(class_name)):
        os.mkdir(train + str(class_name))
    src_path = images_dir + '/'+ filename 
    dst_path = train + str(class_name) + '/' + filename
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %% [markdown]
# # Creating Test data folder

# %%
test_csv=pd.read_csv("data_saved_test.csv")
fichier_test=test_csv.copy()
fichier_test=fichier_test.drop(columns=["Unnamed: 0","image_path","label"])
fichier_test.head()
# Out:
#                                      id label_name
# 0  833a87b0af3b84fe246d2ebf271af177.jpg  Computers
# 1  55195de3873fffaa9e37b041533d7305.jpg    Kitchen
# 2  44b963eb856b4831dfdd21b666593c95.jpg  Computers
# 3  98ad5b99ad96695568d8f143b11ab740.jpg     Beauty
# 4  29b1ca231e10d5269516b80bf9d0dffc.jpg    Watches

# %%
fichier_test.shape
# Out:
# (263, 2)

# %%
import csv

# %%
source = r'C:\Users\kherm\Documents\Openclassrooms\projet 6\Flipkart\Images'
destination = r'C:\Users\kherm\Documents\Openclassrooms\projet 6\Flipkart\test'

with open('data_saved_test.csv') as csvfile:
       reader = csv.DictReader(csvfile)
       for column in reader:
           if os.path.exists(os.path.join(source, column['id'])) and os.stat(os.path.join(source, column['id'])).st_size != 0:
               shutil.copyfile(os.path.join(source, column['id']), os.path.join(destination, column['id']))
